# %%
## Import All Needed Libraries

import os
import gym
import ray
from animalai.envs.arena_config import ArenaConfig
from animalai.envs.gym.environment import AnimalAIGym
from ray.rllib.agents import ppo

from ray.tune import register_env, tune

from ray.rllib.agents.ppo import PPOTrainer
from ray.rllib.models import ModelCatalog
from ray.tune.logger import pretty_print

from cache_model import *
from config import get_cfg
from custom_model import *
# Out:
# WARNING:tensorflow:From /home/azibit/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-04-06 19:33:40,557	WARNING deprecation.py:34 -- DeprecationWarning: `ray.rllib.env.atari_wrappers....` has been deprecated. Use `ray.rllib.env.wrappers.atari_wrappers....` instead. This will raise an error in the future!

# %%
## Reuse Wrapper for AnimalAI Environment

class UnityEnvWrapper(gym.Env):
    def __init__(self, env_config):
        self.vector_index = env_config.vector_index
        self.worker_index = env_config.worker_index
        self.worker_id = env_config["unity_worker_id"] + env_config.worker_index
        self.env = AnimalAIGym(
            environment_filename = "../examples/env/AnimalAI",
            worker_id = self.worker_id,
            flatten_branched = True,
            uint8_visual = True,
            arenas_configurations = ArenaConfig(env_config['arena_to_train'])
        )
        self.action_space = self.env.action_space
        self.observation_space = self.env.observation_space
        
    def reset(self):
        return self.env.reset()
    
    def step(self, action):
        return self.env.step(action)

# %%
## Setup configuration to use

conf = {
    "num_workers": 0,
    "env_config": {
        "unity_worker_id": 67,
        "arena_to_train": '../examples/configurations/curriculum/5.yml'
        },
        "model": {
            "custom_model": 'my_cnn_rnn_model',
            "custom_model_config": {},
        },
        "num_gpus": int(os.environ.get("RLLIB_NUM_GPUS", "2")),
        "num_workers": 1,  # parallelism
        "framework": "torch",
        "train_batch_size": 500,
        
       }
conf
# Out:
# {'num_workers': 1,
#  'env_config': {'unity_worker_id': 67,
#   'arena_to_train': '../examples/configurations/curriculum/5.yml'},
#  'model': {'custom_model': 'my_cnn_rnn_model', 'custom_model_config': {}},
#  'num_gpus': 2,
#  'framework': 'torch',
#  'train_batch_size': 500}

# %%
## Setup and register environment
ray.shutdown()
ray.init(num_cpus=4, num_gpus=2)

# Register custom models so that we can give the ID to the policy trainer
# ModelCatalog.register_custom_model("my_fc_model", MyFCForwardModel)
ModelCatalog.register_custom_model("my_rnn_model", MyRNNModel)
ModelCatalog.register_custom_model("my_convgru_model", MyConvGRUModel)  # NOTE: Only works with image observations.
ModelCatalog.register_custom_model("my_cnn_rnn_model", MyCNNRNNModel)

register_env("unity_env", lambda config: UnityEnvWrapper(config))
# Out:
# 2021-04-06 19:35:22,976	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8266

# %%
trainer = PPOTrainer(config=conf, env= "unity_env")
# Out:
# 2021-04-06 19:35:27,631	INFO trainer.py:643 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=18850) WARNING:tensorflow:From /home/azibit/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=18850) Instructions for updating:
# (pid=18850) non-resource variables are not supported in the long term
# (pid=18850) Found path: /home/azibit/COMS_673/AnimalAI-Olympics/cachey/../examples/env/AnimalAI.x86_64
# (pid=18850) Mono path[0] = '/home/azibit/COMS_673/AnimalAI-Olympics/cachey/../examples/env/AnimalAI_Data/Managed'
# (pid=18850) Mono config path = '/home/azibit/COMS_673/AnimalAI-Olympics/cachey/../examples/env/AnimalAI_Data/MonoBleedingEdge/etc'
# (pid=18850) Preloaded 'lib_burst_generated.so'
# (pid=18850) Preloaded 'libgrpc_csharp_ext.x64.so'
# (pid=18850) Preloaded 'ScreenSelector.so'
# (pid=18850) Display 0 'C32F391 32"': 1920x1080 (primary device).
# (pid=18850) Logging to /home/azibit/.config/unity3d/Unity Technologies/UnityEnvironment/Player.log
# (pid=18850) INFO:mlagents_envs:Connected to Unity environment with package version 0.15.0-preview and communication version 0.15.0
# (pid=18850) INFO:mlagents_envs:Connected new brain:
# (pid=18850) AnimalAI?team=0
# (pid=18850) INFO:gym_unity:1 agents within environment.
# (pid=18850) 2021-04-06 19:35:33,018	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=18850) 2021-04-06 19:35:33,056	WARNING deprecation.py:34 -- DeprecationWarning: `ray.rllib.env.atari_wrappers....` has been deprecated. Use `ray.rllib.env.wrappers.atari_wrappers....` instead. This will raise an error in the future!
# 2021-04-06 19:35:33,176	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# 2021-04-06 19:35:35,251	WARNING util.py:47 -- Install gputil for GPU system monitoring.

# %%
## Train the model
checkpoint = ""
for i in range(1002):
   # Perform one iteration of training the policy with PPO
   result = trainer.train()
   print(pretty_print(result))

   if i % 200 == 0:
       checkpoint = trainer.save()
       print("checkpoint saved at", checkpoint)
# Out:
# (pid=18850) 2021-04-06 19:36:09,868	WARNING deprecation.py:34 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# 2021-04-06 19:36:14,299	WARNING sgd.py:69 -- Not time-shuffling RNN data for SGD.
# custom_metrics: {}
# date: 2021-04-06_19-36-16
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 0.2
#       cur_lr: 5.0e-05
#       entropy: 2.137380027770996
#       entropy_coeff: 0.0
#       kl: 0.025680503621697427
#       policy_loss: -0.08258256614208222
#       total_loss: -0.07367224097251893
#       vf_explained_var: 0.6808925271034241
#       vf_loss: 0.003774236887693405
#   num_steps_sampled: 600
#   num_steps_trained: 600
# iterations_since_restore: 1
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 11.401666666666669
#   ram_util_percent: 43.2
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.0506395508167946
#   mean_env_wait_ms: 5.336339779185773
#   mean_inference_ms: 1.8125786360805722
#   mean_raw_obs_processing_ms: 0.1502005312089714
# time_since_restore: 7.040290832519531
# time_this_iter_s: 7.040290832519531
# time_total_s: 7.040290832519531
# timers:
#   learn_throughput: 232.022
#   learn_time_ms: 2585.962
#   sample_throughput: 134.874
#   sample_time_ms: 4448.59
#   update_time_ms: 2.543
# timestamp: 1617755776
# timesteps_since_restore: 0
# timesteps_total: 600
# training_iteration: 1
#
# checkpoint saved at /home/azibit/ray_results/PPO_unity_env_2021-04-06_19-35-27wu402w3o/checkpoint_1/checkpoint-1
# custom_metrics: {}
# date: 2021-04-06_19-36-22
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 4
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 0.30000000000000004
#       cur_lr: 5.0e-05
#       entropy: 2.136585295200348
#       entropy_coeff: 0.0
#       kl: 0.021599612664431334
#       policy_loss: -0.1341428905725479
#       total_loss: -0.12554464489221573
#       vf_explained_var: 0.8462755084037781
#       vf_loss: 0.002118360309395939
#   num_steps_sampled: 1200
#   num_steps_trained: 1200
# iterations_since_restore: 2
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.4375
#   ram_util_percent: 43.575
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05036305649983803
#   mean_env_wait_ms: 5.145321159211802
#   mean_inference_ms: 1.8123269670885442
#   mean_raw_obs_processing_ms: 0.1393299528910405
# time_since_restore: 13.007147789001465
# time_this_iter_s: 5.966856956481934
# time_total_s: 13.007147789001465
# timers:
#   learn_throughput: 260.214
#   learn_time_ms: 2305.798
#   sample_throughput: 143.133
#   sample_time_ms: 4191.902
#   update_time_ms: 2.543
# timestamp: 1617755782
# timesteps_since_restore: 0
# timesteps_total: 1200
# training_iteration: 2
#
# custom_metrics: {}
# date: 2021-04-06_19-36-29
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 7
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 0.45000000000000007
#       cur_lr: 5.0e-05
#       entropy: 2.1115121841430664
#       entropy_coeff: 0.0
#       kl: 0.02780015058815479
#       policy_loss: -0.06845704615116119
#       total_loss: -0.05296423733234405
#       vf_explained_var: 0.7858710885047913
#       vf_loss: 0.0029827357735484838
#   num_steps_sampled: 1800
#   num_steps_trained: 1800
# iterations_since_restore: 3
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 20.259999999999998
#   ram_util_percent: 43.739999999999995
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05010879475770832
#   mean_env_wait_ms: 5.014643076134638
#   mean_inference_ms: 1.829178459461336
#   mean_raw_obs_processing_ms: 0.13315401071173374
# time_since_restore: 19.558323621749878
# time_this_iter_s: 6.551175832748413
# time_total_s: 19.558323621749878
# timers:
#   learn_throughput: 252.864
#   learn_time_ms: 2372.819
#   sample_throughput: 144.899
#   sample_time_ms: 4140.817
#   update_time_ms: 2.433
# timestamp: 1617755789
# timesteps_since_restore: 0
# timesteps_total: 1800
# training_iteration: 3
#
# custom_metrics: {}
# date: 2021-04-06_19-36-35
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 9
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 0.675
#       cur_lr: 5.0e-05
#       entropy: 2.1031426906585695
#       entropy_coeff: 0.0
#       kl: 0.018472168408334256
#       policy_loss: -0.07237026393413544
#       total_loss: -0.05727575421333313
#       vf_explained_var: 0.8014963865280151
#       vf_loss: 0.002625783788971603
#   num_steps_sampled: 2400
#   num_steps_trained: 2400
# iterations_since_restore: 4
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.977777777777778
#   ram_util_percent: 43.84444444444444
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.0500061450080809
#   mean_env_wait_ms: 4.959086814619077
#   mean_inference_ms: 1.8316459819585367
#   mean_raw_obs_processing_ms: 0.13050256203435467
# time_since_restore: 25.93325448036194
# time_this_iter_s: 6.3749308586120605
# time_total_s: 25.93325448036194
# timers:
#   learn_throughput: 250.687
#   learn_time_ms: 2393.421
#   sample_throughput: 146.911
#   sample_time_ms: 4084.096
#   update_time_ms: 2.357
# timestamp: 1617755795
# timesteps_since_restore: 0
# timesteps_total: 2400
# training_iteration: 4
#
# custom_metrics: {}
# date: 2021-04-06_19-36-42
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 12
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 0.675
#       cur_lr: 5.0e-05
#       entropy: 2.1133060455322266
#       entropy_coeff: 0.0
#       kl: 0.02256700545549393
#       policy_loss: -0.059461528062820436
#       total_loss: -0.03890970945358276
#       vf_explained_var: 0.6873642802238464
#       vf_loss: 0.0053190906066447495
#   num_steps_sampled: 3000
#   num_steps_trained: 3000
# iterations_since_restore: 5
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.72222222222222
#   ram_util_percent: 43.788888888888884
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04988827313732242
#   mean_env_wait_ms: 4.8998135624056856
#   mean_inference_ms: 1.8320210346779104
#   mean_raw_obs_processing_ms: 0.12782415410615752
# time_since_restore: 32.296058177948
# time_this_iter_s: 6.36280369758606
# time_total_s: 32.296058177948
# timers:
#   learn_throughput: 249.832
#   learn_time_ms: 2401.615
#   sample_throughput: 148.081
#   sample_time_ms: 4051.83
#   update_time_ms: 2.337
# timestamp: 1617755802
# timesteps_since_restore: 0
# timesteps_total: 3000
# training_iteration: 5
#
# custom_metrics: {}
# date: 2021-04-06_19-36-48
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 14
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.0125000000000002
#       cur_lr: 5.0e-05
#       entropy: 2.107724189758301
#       entropy_coeff: 0.0
#       kl: 0.013466185703873635
#       policy_loss: -0.11965490654110908
#       total_loss: -0.10234293378889561
#       vf_explained_var: 0.5541435480117798
#       vf_loss: 0.003677461203187704
#   num_steps_sampled: 3600
#   num_steps_trained: 3600
# iterations_since_restore: 6
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.98888888888889
#   ram_util_percent: 43.7
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04982270781576333
#   mean_env_wait_ms: 4.870415788740448
#   mean_inference_ms: 1.8317324069170915
#   mean_raw_obs_processing_ms: 0.12642508970378927
# time_since_restore: 38.68158769607544
# time_this_iter_s: 6.385529518127441
# time_total_s: 38.68158769607544
# timers:
#   learn_throughput: 248.966
#   learn_time_ms: 2409.969
#   sample_throughput: 148.838
#   sample_time_ms: 4031.239
#   update_time_ms: 2.321
# timestamp: 1617755808
# timesteps_since_restore: 0
# timesteps_total: 3600
# training_iteration: 6
# custom_metrics: {}
# date: 2021-04-06_19-36-54
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 16
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.0125000000000002
#       cur_lr: 5.0e-05
#       entropy: 2.098140776157379
#       entropy_coeff: 0.0
#       kl: 0.014817873015999794
#       policy_loss: -0.35353048518300056
#       total_loss: -0.3361012227833271
#       vf_explained_var: 0.7000163793563843
#       vf_loss: 0.002426172693958506
#   num_steps_sampled: 4200
#   num_steps_trained: 4200
# iterations_since_restore: 7
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.31111111111111
#   ram_util_percent: 43.7
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04977695356196197
#   mean_env_wait_ms: 4.8465886540231065
#   mean_inference_ms: 1.8310670823080941
#   mean_raw_obs_processing_ms: 0.1252001627864539
# time_since_restore: 44.73874568939209
# time_this_iter_s: 6.05715799331665
# time_total_s: 44.73874568939209
# timers:
#   learn_throughput: 253.539
#   learn_time_ms: 2366.504
#   sample_throughput: 149.29
#   sample_time_ms: 4019.036
#   update_time_ms: 2.318
# timestamp: 1617755814
# timesteps_since_restore: 0
# timesteps_total: 4200
# training_iteration: 7
#
# custom_metrics: {}
# date: 2021-04-06_19-37-01
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 19
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.0125000000000002
#       cur_lr: 5.0e-05
#       entropy: 2.069659423828125
#       entropy_coeff: 0.0
#       kl: 0.019400161132216452
#       policy_loss: -0.08338068127632141
#       total_loss: -0.06148844361305237
#       vf_explained_var: 0.5067057609558105
#       vf_loss: 0.0022495657205581663
#   num_steps_sampled: 4800
#   num_steps_trained: 4800
# iterations_since_restore: 8
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.08888888888889
#   ram_util_percent: 43.58888888888889
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04971306268004695
#   mean_env_wait_ms: 4.8194340218234375
#   mean_inference_ms: 1.830016325513176
#   mean_raw_obs_processing_ms: 0.12388937416586328
# time_since_restore: 51.185853242874146
# time_this_iter_s: 6.447107553482056
# time_total_s: 51.185853242874146
# timers:
#   learn_throughput: 252.291
#   learn_time_ms: 2378.208
#   sample_throughput: 149.463
#   sample_time_ms: 4014.382
#   update_time_ms: 2.28
# timestamp: 1617755821
# timesteps_since_restore: 0
# timesteps_total: 4800
# training_iteration: 8
#
# custom_metrics: {}
# date: 2021-04-06_19-37-07
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 21
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.0125000000000002
#       cur_lr: 5.0e-05
#       entropy: 2.0308231830596926
#       entropy_coeff: 0.0
#       kl: 0.021413147635757922
#       policy_loss: -0.100866037607193
#       total_loss: -0.0763994038105011
#       vf_explained_var: 0.615331768989563
#       vf_loss: 0.0027858179062604906
#   num_steps_sampled: 5400
#   num_steps_trained: 5400
# iterations_since_restore: 9
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.633333333333336
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04967686222588745
#   mean_env_wait_ms: 4.8050787277580325
#   mean_inference_ms: 1.829215763539378
#   mean_raw_obs_processing_ms: 0.12314192528056697
# time_since_restore: 57.59020781517029
# time_this_iter_s: 6.404354572296143
# time_total_s: 57.59020781517029
# timers:
#   learn_throughput: 251.569
#   learn_time_ms: 2385.034
#   sample_throughput: 149.69
#   sample_time_ms: 4008.277
#   update_time_ms: 2.262
# timestamp: 1617755827
# timesteps_since_restore: 0
# timesteps_total: 5400
# training_iteration: 9
#
# custom_metrics: {}
# date: 2021-04-06_19-37-13
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 24
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.034413743019104
#       entropy_coeff: 0.0
#       kl: 0.011782366689294577
#       policy_loss: -0.06677221357822419
#       total_loss: -0.04467085897922516
#       vf_explained_var: 0.399402916431427
#       vf_loss: 0.00420688595622778
#   num_steps_sampled: 6000
#   num_steps_trained: 6000
# iterations_since_restore: 10
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.288888888888888
#   ram_util_percent: 43.53333333333333
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049625235666734234
#   mean_env_wait_ms: 4.786718378923664
#   mean_inference_ms: 1.8280603797438564
#   mean_raw_obs_processing_ms: 0.12223894365027164
# time_since_restore: 63.98305892944336
# time_this_iter_s: 6.392851114273071
# time_total_s: 63.98305892944336
# timers:
#   learn_throughput: 250.824
#   learn_time_ms: 2392.114
#   sample_throughput: 149.978
#   sample_time_ms: 4000.587
#   update_time_ms: 2.244
# timestamp: 1617755833
# timesteps_since_restore: 0
# timesteps_total: 6000
# training_iteration: 10
#
# custom_metrics: {}
# date: 2021-04-06_19-37-20
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 26
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0664084911346436
#       entropy_coeff: 0.0
#       kl: 0.015410769917070865
#       policy_loss: -0.21661945283412934
#       total_loss: -0.19079475998878478
#       vf_explained_var: 0.7231016755104065
#       vf_loss: 0.0024196049314923586
#   num_steps_sampled: 6600
#   num_steps_trained: 6600
# iterations_since_restore: 11
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.110000000000003
#   ram_util_percent: 43.53
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049596815685486226
#   mean_env_wait_ms: 4.776578071263159
#   mean_inference_ms: 1.8273498672152515
#   mean_raw_obs_processing_ms: 0.12170620379542327
# time_since_restore: 70.42027997970581
# time_this_iter_s: 6.437221050262451
# time_total_s: 70.42027997970581
# timers:
#   learn_throughput: 252.071
#   learn_time_ms: 2380.283
#   sample_throughput: 151.814
#   sample_time_ms: 3952.197
#   update_time_ms: 2.182
# timestamp: 1617755840
# timesteps_since_restore: 0
# timesteps_total: 6600
# training_iteration: 11
#
# custom_metrics: {}
# date: 2021-04-06_19-37-26
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 28
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0353498458862305
#       entropy_coeff: 0.0
#       kl: 0.011472902027890086
#       policy_loss: -0.11563503928482533
#       total_loss: -0.09467903897166252
#       vf_explained_var: 0.6954832077026367
#       vf_loss: 0.003531529597239569
#   num_steps_sampled: 7200
#   num_steps_trained: 7200
# iterations_since_restore: 12
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.9125
#   ram_util_percent: 43.5625
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04957653942734067
#   mean_env_wait_ms: 4.767506983614395
#   mean_inference_ms: 1.8267077148546933
#   mean_raw_obs_processing_ms: 0.12120385901797169
# time_since_restore: 76.36436176300049
# time_this_iter_s: 5.944081783294678
# time_total_s: 76.36436176300049
# timers:
#   learn_throughput: 252.456
#   learn_time_ms: 2376.65
#   sample_throughput: 151.762
#   sample_time_ms: 3953.561
#   update_time_ms: 2.157
# timestamp: 1617755846
# timesteps_since_restore: 0
# timesteps_total: 7200
# training_iteration: 12
# custom_metrics: {}
# date: 2021-04-06_19-37-32
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 31
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0195152282714846
#       entropy_coeff: 0.0
#       kl: 0.01767448764294386
#       policy_loss: -0.04557156562805176
#       total_loss: -0.016058385372161865
#       vf_explained_var: 0.6289110779762268
#       vf_loss: 0.002670068759471178
#   num_steps_sampled: 7800
#   num_steps_trained: 7800
# iterations_since_restore: 13
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.288888888888888
#   ram_util_percent: 43.51111111111111
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049548806132827174
#   mean_env_wait_ms: 4.755551979736868
#   mean_inference_ms: 1.8257939934794234
#   mean_raw_obs_processing_ms: 0.12059725070362547
# time_since_restore: 82.76841640472412
# time_this_iter_s: 6.404054641723633
# time_total_s: 82.76841640472412
# timers:
#   learn_throughput: 252.988
#   learn_time_ms: 2371.657
#   sample_throughput: 152.137
#   sample_time_ms: 3943.821
#   update_time_ms: 2.174
# timestamp: 1617755852
# timesteps_since_restore: 0
# timesteps_total: 7800
# training_iteration: 13
#
# custom_metrics: {}
# date: 2021-04-06_19-37-39
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 33
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.038782167434692
#       entropy_coeff: 0.0
#       kl: 0.014268168061971665
#       policy_loss: -0.1088418960571289
#       total_loss: -0.08492505550384521
#       vf_explained_var: 0.689674973487854
#       vf_loss: 0.002247076574712992
#   num_steps_sampled: 8400
#   num_steps_trained: 8400
# iterations_since_restore: 14
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.644444444444442
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049529949964924
#   mean_env_wait_ms: 4.748743197829377
#   mean_inference_ms: 1.8252181996976187
#   mean_raw_obs_processing_ms: 0.1202387440384699
# time_since_restore: 89.2070529460907
# time_this_iter_s: 6.438636541366577
# time_total_s: 89.2070529460907
# timers:
#   learn_throughput: 252.914
#   learn_time_ms: 2372.346
#   sample_throughput: 151.919
#   sample_time_ms: 3949.479
#   update_time_ms: 2.181
# timestamp: 1617755859
# timesteps_since_restore: 0
# timesteps_total: 8400
# training_iteration: 14
#
# custom_metrics: {}
# date: 2021-04-06_19-37-45
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 36
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0580146312713623
#       entropy_coeff: 0.0
#       kl: 0.012644308991730214
#       policy_loss: -0.013868063688278198
#       total_loss: 0.008783894777297973
#       vf_explained_var: 0.6778194904327393
#       vf_loss: 0.0034484222531318666
#   num_steps_sampled: 9000
#   num_steps_trained: 9000
# iterations_since_restore: 15
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.34
#   ram_util_percent: 43.540000000000006
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04950700528022738
#   mean_env_wait_ms: 4.739551072552137
#   mean_inference_ms: 1.8244844807516105
#   mean_raw_obs_processing_ms: 0.11978539529204801
# time_since_restore: 95.62651491165161
# time_this_iter_s: 6.419461965560913
# time_total_s: 95.62651491165161
# timers:
#   learn_throughput: 252.549
#   learn_time_ms: 2375.777
#   sample_throughput: 151.833
#   sample_time_ms: 3951.71
#   update_time_ms: 2.158
# timestamp: 1617755865
# timesteps_since_restore: 0
# timesteps_total: 9000
# training_iteration: 15
#
# custom_metrics: {}
# date: 2021-04-06_19-37-52
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 38
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.994603681564331
#       entropy_coeff: 0.0
#       kl: 0.013553301803767681
#       policy_loss: -0.1700427144765854
#       total_loss: -0.1473751962184906
#       vf_explained_var: 0.6642016768455505
#       vf_loss: 0.0020834372378885748
#   num_steps_sampled: 9600
#   num_steps_trained: 9600
# iterations_since_restore: 16
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.944444444444446
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04949147181285889
#   mean_env_wait_ms: 4.734128239392587
#   mean_inference_ms: 1.8240178197965886
#   mean_raw_obs_processing_ms: 0.11950744504711762
# time_since_restore: 102.04653787612915
# time_this_iter_s: 6.420022964477539
# time_total_s: 102.04653787612915
# timers:
#   learn_throughput: 252.459
#   learn_time_ms: 2376.621
#   sample_throughput: 151.734
#   sample_time_ms: 3954.288
#   update_time_ms: 2.188
# timestamp: 1617755872
# timesteps_since_restore: 0
# timesteps_total: 9600
# training_iteration: 16
#
# custom_metrics: {}
# date: 2021-04-06_19-37-58
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 40
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.047349512577057
#       entropy_coeff: 0.0
#       kl: 0.013619503937661648
#       policy_loss: -0.15035434812307358
#       total_loss: -0.1253184899687767
#       vf_explained_var: 0.6886165142059326
#       vf_loss: 0.004351228359155357
#   num_steps_sampled: 10200
#   num_steps_trained: 10200
# iterations_since_restore: 17
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.362499999999997
#   ram_util_percent: 43.5625
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04947691589253988
#   mean_env_wait_ms: 4.728978042728844
#   mean_inference_ms: 1.8235569096478017
#   mean_raw_obs_processing_ms: 0.11923141388693825
# time_since_restore: 107.95702838897705
# time_this_iter_s: 5.9104905128479
# time_total_s: 107.95702838897705
# timers:
#   learn_throughput: 253.669
#   learn_time_ms: 2365.289
#   sample_throughput: 151.863
#   sample_time_ms: 3950.936
#   update_time_ms: 2.201
# timestamp: 1617755878
# timesteps_since_restore: 0
# timesteps_total: 10200
# training_iteration: 17
#
# custom_metrics: {}
# date: 2021-04-06_19-38-04
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 43
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0557793378829956
#       entropy_coeff: 0.0
#       kl: 0.012836678791791201
#       policy_loss: -0.08058646321296692
#       total_loss: -0.057438650727272035
#       vf_explained_var: 0.7851787805557251
#       vf_loss: 0.0036521080881357195
#   num_steps_sampled: 10800
#   num_steps_trained: 10800
# iterations_since_restore: 18
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.799999999999997
#   ram_util_percent: 43.51111111111111
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04945729628431622
#   mean_env_wait_ms: 4.721581903274854
#   mean_inference_ms: 1.8229073321662552
#   mean_raw_obs_processing_ms: 0.11887772419354627
# time_since_restore: 114.31609272956848
# time_this_iter_s: 6.359064340591431
# time_total_s: 114.31609272956848
# timers:
#   learn_throughput: 253.584
#   learn_time_ms: 2366.077
#   sample_throughput: 152.235
#   sample_time_ms: 3941.267
#   update_time_ms: 2.236
# timestamp: 1617755884
# timesteps_since_restore: 0
# timesteps_total: 10800
# training_iteration: 18
# custom_metrics: {}
# date: 2021-04-06_19-38-10
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 45
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0090863704681396
#       entropy_coeff: 0.0
#       kl: 0.015280828066170215
#       policy_loss: -0.10137143731117249
#       total_loss: -0.07410805821418762
#       vf_explained_var: 0.7234721779823303
#       vf_loss: 0.004055599588900805
#   num_steps_sampled: 11400
#   num_steps_trained: 11400
# iterations_since_restore: 19
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.988888888888887
#   ram_util_percent: 43.53333333333333
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04944444948000758
#   mean_env_wait_ms: 4.717093856500936
#   mean_inference_ms: 1.8225235588604145
#   mean_raw_obs_processing_ms: 0.11866771695614554
# time_since_restore: 120.71984505653381
# time_this_iter_s: 6.403752326965332
# time_total_s: 120.71984505653381
# timers:
#   learn_throughput: 253.448
#   learn_time_ms: 2367.352
#   sample_throughput: 152.289
#   sample_time_ms: 3939.884
#   update_time_ms: 2.242
# timestamp: 1617755890
# timesteps_since_restore: 0
# timesteps_total: 11400
# training_iteration: 19
#
# custom_metrics: {}
# date: 2021-04-06_19-38-17
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 48
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.9934417009353638
#       entropy_coeff: 0.0
#       kl: 0.01562326941639185
#       policy_loss: -0.13181683868169786
#       total_loss: -0.1046859309077263
#       vf_explained_var: 0.5904766321182251
#       vf_loss: 0.0034030830953270196
#   num_steps_sampled: 12000
#   num_steps_trained: 12000
# iterations_since_restore: 20
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.369999999999997
#   ram_util_percent: 43.540000000000006
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04942658073681305
#   mean_env_wait_ms: 4.711017827634114
#   mean_inference_ms: 1.8219609981762863
#   mean_raw_obs_processing_ms: 0.11838889912351137
# time_since_restore: 127.15055465698242
# time_this_iter_s: 6.430709600448608
# time_total_s: 127.15055465698242
# timers:
#   learn_throughput: 253.28
#   learn_time_ms: 2368.916
#   sample_throughput: 152.204
#   sample_time_ms: 3942.089
#   update_time_ms: 2.263
# timestamp: 1617755897
# timesteps_since_restore: 0
# timesteps_total: 12000
# training_iteration: 20
#
# custom_metrics: {}
# date: 2021-04-06_19-38-23
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 50
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.982043194770813
#       entropy_coeff: 0.0
#       kl: 0.01447819285094738
#       policy_loss: -0.15775571689009665
#       total_loss: -0.1319689691066742
#       vf_explained_var: 0.5057579278945923
#       vf_loss: 0.003797987732104957
#   num_steps_sampled: 12600
#   num_steps_trained: 12600
# iterations_since_restore: 21
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.58888888888889
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04941531643864552
#   mean_env_wait_ms: 4.707238895604262
#   mean_inference_ms: 1.821618994211649
#   mean_raw_obs_processing_ms: 0.11821875262372529
# time_since_restore: 133.54176473617554
# time_this_iter_s: 6.391210079193115
# time_total_s: 133.54176473617554
# timers:
#   learn_throughput: 253.367
#   learn_time_ms: 2368.108
#   sample_throughput: 152.354
#   sample_time_ms: 3938.197
#   update_time_ms: 2.306
# timestamp: 1617755903
# timesteps_since_restore: 0
# timesteps_total: 12600
# training_iteration: 21
#
# custom_metrics: {}
# date: 2021-04-06_19-38-29
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 52
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.9983348548412323
#       entropy_coeff: 0.0
#       kl: 0.012654230697080493
#       policy_loss: -0.349708354100585
#       total_loss: -0.326732175424695
#       vf_explained_var: 0.687187910079956
#       vf_loss: 0.0037575828609988093
#   num_steps_sampled: 13200
#   num_steps_trained: 13200
# iterations_since_restore: 22
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 19.5
#   ram_util_percent: 43.55
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04940584223606628
#   mean_env_wait_ms: 4.7036126161246665
#   mean_inference_ms: 1.8212949098021374
#   mean_raw_obs_processing_ms: 0.11804993563597188
# time_since_restore: 139.45308184623718
# time_this_iter_s: 5.9113171100616455
# time_total_s: 139.45308184623718
# timers:
#   learn_throughput: 253.341
#   learn_time_ms: 2368.352
#   sample_throughput: 152.49
#   sample_time_ms: 3934.674
#   update_time_ms: 2.304
# timestamp: 1617755909
# timesteps_since_restore: 0
# timesteps_total: 13200
# training_iteration: 22
#
# custom_metrics: {}
# date: 2021-04-06_19-38-36
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 55
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0176255226135256
#       entropy_coeff: 0.0
#       kl: 0.013432729803025723
#       policy_loss: -0.10056981444358826
#       total_loss: -0.07758579850196838
#       vf_explained_var: 0.8469802141189575
#       vf_loss: 0.0025830716360360382
#   num_steps_sampled: 13800
#   num_steps_trained: 13800
# iterations_since_restore: 23
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.955555555555556
#   ram_util_percent: 43.51111111111111
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049392681821880606
#   mean_env_wait_ms: 4.698457358411172
#   mean_inference_ms: 1.820838824065982
#   mean_raw_obs_processing_ms: 0.1178302049092725
# time_since_restore: 145.9076578617096
# time_this_iter_s: 6.454576015472412
# time_total_s: 145.9076578617096
# timers:
#   learn_throughput: 252.483
#   learn_time_ms: 2376.398
#   sample_throughput: 152.606
#   sample_time_ms: 3931.703
#   update_time_ms: 2.286
# timestamp: 1617755916
# timesteps_since_restore: 0
# timesteps_total: 13800
# training_iteration: 23
#
# custom_metrics: {}
# date: 2021-04-06_19-38-42
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 57
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0089679479599
#       entropy_coeff: 0.0
#       kl: 0.013700531888753175
#       policy_loss: -0.09362980760633946
#       total_loss: -0.0672315765172243
#       vf_explained_var: 0.7278014421463013
#       vf_loss: 0.005590552883222699
#   num_steps_sampled: 14400
#   num_steps_trained: 14400
# iterations_since_restore: 24
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.58
#   ram_util_percent: 43.529999999999994
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049384133123700824
#   mean_env_wait_ms: 4.695157916205223
#   mean_inference_ms: 1.8205430901546313
#   mean_raw_obs_processing_ms: 0.11769199895042137
# time_since_restore: 152.24062609672546
# time_this_iter_s: 6.332968235015869
# time_total_s: 152.24062609672546
# timers:
#   learn_throughput: 252.711
#   learn_time_ms: 2374.253
#   sample_throughput: 152.932
#   sample_time_ms: 3923.304
#   update_time_ms: 2.302
# timestamp: 1617755922
# timesteps_since_restore: 0
# timesteps_total: 14400
# training_iteration: 24
# custom_metrics: {}
# date: 2021-04-06_19-38-48
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 60
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.9640355110168457
#       entropy_coeff: 0.0
#       kl: 0.015743762627243994
#       policy_loss: -0.09148939847946166
#       total_loss: -0.06465781331062317
#       vf_explained_var: 0.7506099343299866
#       vf_loss: 0.0029207180719822644
#   num_steps_sampled: 15000
#   num_steps_trained: 15000
# iterations_since_restore: 25
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.822222222222223
#   ram_util_percent: 43.54444444444445
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04937198798613792
#   mean_env_wait_ms: 4.690576386888591
#   mean_inference_ms: 1.8201546508135384
#   mean_raw_obs_processing_ms: 0.11750745781632155
# time_since_restore: 158.66726565361023
# time_this_iter_s: 6.426639556884766
# time_total_s: 158.66726565361023
# timers:
#   learn_throughput: 252.724
#   learn_time_ms: 2374.13
#   sample_throughput: 152.901
#   sample_time_ms: 3924.102
#   update_time_ms: 2.332
# timestamp: 1617755928
# timesteps_since_restore: 0
# timesteps_total: 15000
# training_iteration: 25
#
# custom_metrics: {}
# date: 2021-04-06_19-38-55
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 62
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0156862497329713
#       entropy_coeff: 0.0
#       kl: 0.015214418061077595
#       policy_loss: -0.13638143241405487
#       total_loss: -0.10841849893331527
#       vf_explained_var: 0.6643224358558655
#       vf_loss: 0.004856026032939553
#   num_steps_sampled: 15600
#   num_steps_trained: 15600
# iterations_since_restore: 26
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.933333333333334
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.049364560482315224
#   mean_env_wait_ms: 4.687633760989321
#   mean_inference_ms: 1.8199087599823176
#   mean_raw_obs_processing_ms: 0.11738863375443426
# time_since_restore: 165.02791047096252
# time_this_iter_s: 6.360644817352295
# time_total_s: 165.02791047096252
# timers:
#   learn_throughput: 252.657
#   learn_time_ms: 2374.765
#   sample_throughput: 153.157
#   sample_time_ms: 3917.553
#   update_time_ms: 2.291
# timestamp: 1617755935
# timesteps_since_restore: 0
# timesteps_total: 15600
# training_iteration: 26
#
# custom_metrics: {}
# date: 2021-04-06_19-39-01
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 64
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.9990849196910858
#       entropy_coeff: 0.0
#       kl: 0.014197333715856075
#       policy_loss: -0.19206488132476807
#       total_loss: -0.16686018370091915
#       vf_explained_var: 0.6134762167930603
#       vf_loss: 0.0036425074795261025
#   num_steps_sampled: 16200
#   num_steps_trained: 16200
# iterations_since_restore: 27
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.7
#   ram_util_percent: 43.5625
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04935729402984268
#   mean_env_wait_ms: 4.684713013772177
#   mean_inference_ms: 1.819661796834486
#   mean_raw_obs_processing_ms: 0.11727159100385495
# time_since_restore: 170.88492012023926
# time_this_iter_s: 5.857009649276733
# time_total_s: 170.88492012023926
# timers:
#   learn_throughput: 252.684
#   learn_time_ms: 2374.503
#   sample_throughput: 153.357
#   sample_time_ms: 3912.444
#   update_time_ms: 2.292
# timestamp: 1617755941
# timesteps_since_restore: 0
# timesteps_total: 16200
# training_iteration: 27
#
# custom_metrics: {}
# date: 2021-04-06_19-39-07
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 67
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 1.9906135559082032
#       entropy_coeff: 0.0
#       kl: 0.012811973318457603
#       policy_loss: -0.09678165167570114
#       total_loss: -0.07397872060537339
#       vf_explained_var: 0.5967451930046082
#       vf_loss: 0.0033447388326749206
#   num_steps_sampled: 16800
#   num_steps_trained: 16800
# iterations_since_restore: 28
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.62222222222222
#   ram_util_percent: 43.51111111111111
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.0493469435504588
#   mean_env_wait_ms: 4.6805547106388685
#   mean_inference_ms: 1.8193216537120578
#   mean_raw_obs_processing_ms: 0.11711526311662132
# time_since_restore: 177.26587796211243
# time_this_iter_s: 6.380957841873169
# time_total_s: 177.26587796211243
# timers:
#   learn_throughput: 252.799
#   learn_time_ms: 2373.431
#   sample_throughput: 153.23
#   sample_time_ms: 3915.685
#   update_time_ms: 2.312
# timestamp: 1617755947
# timesteps_since_restore: 0
# timesteps_total: 16800
# training_iteration: 28
#
# custom_metrics: {}
# date: 2021-04-06_19-39-13
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 69
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0381209373474123
#       entropy_coeff: 0.0
#       kl: 0.01293007805943489
#       policy_loss: -0.08709673881530762
#       total_loss: -0.060943222045898436
#       vf_explained_var: 0.51707923412323
#       vf_loss: 0.00651596300303936
#   num_steps_sampled: 17400
#   num_steps_trained: 17400
# iterations_since_restore: 29
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.844444444444445
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04934043326033925
#   mean_env_wait_ms: 4.677856205600843
#   mean_inference_ms: 1.8191080470145475
#   mean_raw_obs_processing_ms: 0.11701683390987194
# time_since_restore: 183.59744787216187
# time_this_iter_s: 6.3315699100494385
# time_total_s: 183.59744787216187
# timers:
#   learn_throughput: 252.798
#   learn_time_ms: 2373.433
#   sample_throughput: 153.514
#   sample_time_ms: 3908.445
#   update_time_ms: 2.326
# timestamp: 1617755953
# timesteps_since_restore: 0
# timesteps_total: 17400
# training_iteration: 29
#
# custom_metrics: {}
# date: 2021-04-06_19-39-20
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 72
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.0562108516693116
#       entropy_coeff: 0.0
#       kl: 0.015092183463275432
#       policy_loss: -0.024521073698997496
#       total_loss: 0.0016000896692276
#       vf_explained_var: 0.6313669085502625
#       vf_loss: 0.003199925646185875
#   num_steps_sampled: 18000
#   num_steps_trained: 18000
# iterations_since_restore: 30
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.32
#   ram_util_percent: 43.56
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04933150082651072
#   mean_env_wait_ms: 4.67389953119641
#   mean_inference_ms: 1.8188043772615303
#   mean_raw_obs_processing_ms: 0.11688346822976856
# time_since_restore: 190.01442551612854
# time_this_iter_s: 6.416977643966675
# time_total_s: 190.01442551612854
# timers:
#   learn_throughput: 252.027
#   learn_time_ms: 2380.697
#   sample_throughput: 153.854
#   sample_time_ms: 3899.797
#   update_time_ms: 2.317
# timestamp: 1617755960
# timesteps_since_restore: 0
# timesteps_total: 18000
# training_iteration: 30
# custom_metrics: {}
# date: 2021-04-06_19-39-26
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 74
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 1.5187500000000003
#       cur_lr: 5.0e-05
#       entropy: 2.057873773574829
#       entropy_coeff: 0.0
#       kl: 0.0173580726608634
#       policy_loss: -0.1436479866504669
#       total_loss: -0.1139593929052353
#       vf_explained_var: 0.7224838137626648
#       vf_loss: 0.0033260118681937454
#   num_steps_sampled: 18600
#   num_steps_trained: 18600
# iterations_since_restore: 31
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 18.577777777777776
#   ram_util_percent: 43.52222222222222
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.04932578133981108
#   mean_env_wait_ms: 4.671388996572617
#   mean_inference_ms: 1.8186092249809016
#   mean_raw_obs_processing_ms: 0.11679763505617134
# time_since_restore: 196.37671065330505
# time_this_iter_s: 6.362285137176514
# time_total_s: 196.37671065330505
# timers:
#   learn_throughput: 252.113
#   learn_time_ms: 2379.886
#   sample_throughput: 153.936
#   sample_time_ms: 3897.719
#   update_time_ms: 2.316
# ...
#   mean_inference_ms: 2.084907547781255
#   mean_raw_obs_processing_ms: 0.12172569238877991
# time_since_restore: 6406.796052932739
# time_this_iter_s: 7.186418056488037
# time_total_s: 6406.796052932739
# timers:
#   learn_throughput: 247.292
#   learn_time_ms: 2426.281
#   sample_throughput: 131.188
#   sample_time_ms: 4573.582
#   update_time_ms: 2.473
# timestamp: 1617762190
# timesteps_since_restore: 0
# timesteps_total: 595200
# training_iteration: 992
#
# custom_metrics: {}
# date: 2021-04-06_21-23-17
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2383
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9638111293315887
#       entropy_coeff: 0.0
#       kl: 0.009997768211178482
#       policy_loss: -0.30169443786144257
#       total_loss: -0.26099318265914917
#       vf_explained_var: 0.6472788453102112
#       vf_loss: 0.006537004024721682
#   num_steps_sampled: 595800
#   num_steps_trained: 595800
# iterations_since_restore: 993
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 37.233333333333334
#   ram_util_percent: 57.13333333333334
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05252468075398233
#   mean_env_wait_ms: 4.732037717245663
#   mean_inference_ms: 2.085104737920916
#   mean_raw_obs_processing_ms: 0.12173638583563406
# time_since_restore: 6413.720059394836
# time_this_iter_s: 6.924006462097168
# time_total_s: 6413.720059394836
# timers:
#   learn_throughput: 247.067
#   learn_time_ms: 2428.494
#   sample_throughput: 130.863
#   sample_time_ms: 4584.956
#   update_time_ms: 2.479
# timestamp: 1617762197
# timesteps_since_restore: 0
# timesteps_total: 595800
# training_iteration: 993
#
# custom_metrics: {}
# date: 2021-04-06_21-23-24
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 2386
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9458861649036407
#       entropy_coeff: 0.0
#       kl: 0.010841708863154054
#       policy_loss: -0.1410534307360649
#       total_loss: -0.0998319536447525
#       vf_explained_var: 0.7088082432746887
#       vf_loss: 0.004173308960162103
#   num_steps_sampled: 596400
#   num_steps_trained: 596400
# iterations_since_restore: 994
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.36363636363637
#   ram_util_percent: 57.0909090909091
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05253230911050199
#   mean_env_wait_ms: 4.732562483654239
#   mean_inference_ms: 2.0853982592270217
#   mean_raw_obs_processing_ms: 0.12175277719417911
# time_since_restore: 6420.855610847473
# time_this_iter_s: 7.135551452636719
# time_total_s: 6420.855610847473
# timers:
#   learn_throughput: 246.964
#   learn_time_ms: 2429.499
#   sample_throughput: 130.357
#   sample_time_ms: 4602.741
#   update_time_ms: 2.456
# timestamp: 1617762204
# timesteps_since_restore: 0
# timesteps_total: 596400
# training_iteration: 994
#
# custom_metrics: {}
# date: 2021-04-06_21-23-31
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2388
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9045008718967438
#       entropy_coeff: 0.0
#       kl: 0.009562645107507706
#       policy_loss: -0.20391163602471352
#       total_loss: -0.16816947609186172
#       vf_explained_var: 0.8149164915084839
#       vf_loss: 0.003064790682401508
#   num_steps_sampled: 597000
#   num_steps_trained: 597000
# iterations_since_restore: 995
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.85
#   ram_util_percent: 57.1
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.052537351910070494
#   mean_env_wait_ms: 4.732909300421068
#   mean_inference_ms: 2.08559165122417
#   mean_raw_obs_processing_ms: 0.12176366128937012
# time_since_restore: 6427.920788049698
# time_this_iter_s: 7.0651772022247314
# time_total_s: 6427.920788049698
# timers:
#   learn_throughput: 248.009
#   learn_time_ms: 2419.265
#   sample_throughput: 130.227
#   sample_time_ms: 4607.329
#   update_time_ms: 2.474
# timestamp: 1617762211
# timesteps_since_restore: 0
# timesteps_total: 597000
# training_iteration: 995
#
# custom_metrics: {}
# date: 2021-04-06_21-23-38
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 2391
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 1.0854934751987457
#       entropy_coeff: 0.0
#       kl: 0.012902114307507873
#       policy_loss: -0.09500820934772491
#       total_loss: -0.04810549318790436
#       vf_explained_var: 0.7969147562980652
#       vf_loss: 0.0028137557674199343
#   num_steps_sampled: 597600
#   num_steps_trained: 597600
# iterations_since_restore: 996
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.42
#   ram_util_percent: 57.14000000000001
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05254490412983234
#   mean_env_wait_ms: 4.73342464078081
#   mean_inference_ms: 2.085882638870178
#   mean_raw_obs_processing_ms: 0.12177981832449175
# time_since_restore: 6434.942939519882
# time_this_iter_s: 7.022151470184326
# time_total_s: 6434.942939519882
# timers:
#   learn_throughput: 248.162
#   learn_time_ms: 2417.78
#   sample_throughput: 130.265
#   sample_time_ms: 4606.012
#   update_time_ms: 2.455
# timestamp: 1617762218
# timesteps_since_restore: 0
# timesteps_total: 597600
# training_iteration: 996
# custom_metrics: {}
# date: 2021-04-06_21-23-45
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2393
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9850463718175888
#       entropy_coeff: 0.0
#       kl: 0.012543221702799201
#       policy_loss: -0.0697830319404602
#       total_loss: -0.02242763340473175
#       vf_explained_var: 0.7762529850006104
#       vf_loss: 0.004492853186093271
#   num_steps_sampled: 598200
#   num_steps_trained: 598200
# iterations_since_restore: 997
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.51
#   ram_util_percent: 57.17
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05254994529322733
#   mean_env_wait_ms: 4.733765563272187
#   mean_inference_ms: 2.0860769988909906
#   mean_raw_obs_processing_ms: 0.12179046924469394
# time_since_restore: 6441.896879434586
# time_this_iter_s: 6.953939914703369
# time_total_s: 6441.896879434586
# timers:
#   learn_throughput: 248.267
#   learn_time_ms: 2416.75
#   sample_throughput: 130.199
#   sample_time_ms: 4608.347
#   update_time_ms: 2.505
# timestamp: 1617762225
# timesteps_since_restore: 0
# timesteps_total: 598200
# training_iteration: 997
#
# custom_metrics: {}
# date: 2021-04-06_21-23-52
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2395
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.8686380162835121
#       entropy_coeff: 0.0
#       kl: 0.010192762536462396
#       policy_loss: -0.3018492478877306
#       total_loss: -0.26183626893907785
#       vf_explained_var: 0.5598430633544922
#       vf_loss: 0.005182399938348681
#   num_steps_sampled: 598800
#   num_steps_trained: 598800
# iterations_since_restore: 998
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 37.1
#   ram_util_percent: 57.20000000000001
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05255507349072488
#   mean_env_wait_ms: 4.7341094560459815
#   mean_inference_ms: 2.086275100914749
#   mean_raw_obs_processing_ms: 0.12180119978196374
# time_since_restore: 6448.911240816116
# time_this_iter_s: 7.014361381530762
# time_total_s: 6448.911240816116
# timers:
#   learn_throughput: 248.036
#   learn_time_ms: 2419.006
#   sample_throughput: 129.653
#   sample_time_ms: 4627.743
#   update_time_ms: 2.464
# timestamp: 1617762232
# timesteps_since_restore: 0
# timesteps_total: 598800
# training_iteration: 998
#
# custom_metrics: {}
# date: 2021-04-06_21-23-59
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 2398
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 1.0761171728372574
#       entropy_coeff: 0.0
#       kl: 0.010842921445146203
#       policy_loss: -0.0775137972086668
#       total_loss: -0.03650384023785591
#       vf_explained_var: 0.7740918397903442
#       vf_loss: 0.003957665176130831
#   num_steps_sampled: 599400
#   num_steps_trained: 599400
# iterations_since_restore: 999
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.97
#   ram_util_percent: 57.16000000000001
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05256268541818057
#   mean_env_wait_ms: 4.734614433539082
#   mean_inference_ms: 2.0865659602372206
#   mean_raw_obs_processing_ms: 0.12181727361679467
# time_since_restore: 6455.964990854263
# time_this_iter_s: 7.053750038146973
# time_total_s: 6455.964990854263
# timers:
#   learn_throughput: 247.36
#   learn_time_ms: 2425.611
#   sample_throughput: 129.713
#   sample_time_ms: 4625.592
#   update_time_ms: 2.36
# timestamp: 1617762239
# timesteps_since_restore: 0
# timesteps_total: 599400
# training_iteration: 999
#
# custom_metrics: {}
# date: 2021-04-06_21-24-06
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2400
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9463724195957184
#       entropy_coeff: 0.0
#       kl: 0.011775746941566467
#       policy_loss: -0.13550536893308163
#       total_loss: -0.09316018968820572
#       vf_explained_var: 0.8142722845077515
#       vf_loss: 0.002105248800944537
#   num_steps_sampled: 600000
#   num_steps_trained: 600000
# iterations_since_restore: 1000
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 37.83
#   ram_util_percent: 57.120000000000005
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.052567760497329453
#   mean_env_wait_ms: 4.734951468240248
#   mean_inference_ms: 2.086759348885375
#   mean_raw_obs_processing_ms: 0.12182792299109435
# time_since_restore: 6463.086409568787
# time_this_iter_s: 7.121418714523315
# time_total_s: 6463.086409568787
# timers:
#   learn_throughput: 247.426
#   learn_time_ms: 2424.963
#   sample_throughput: 129.391
#   sample_time_ms: 4637.107
#   update_time_ms: 2.355
# timestamp: 1617762246
# timesteps_since_restore: 0
# timesteps_total: 600000
# training_iteration: 1000
#
# custom_metrics: {}
# date: 2021-04-06_21-24-13
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 3
# episodes_total: 2403
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 0.9819326847791672
#       entropy_coeff: 0.0
#       kl: 0.011580641730688512
#       policy_loss: 0.030883722007274628
#       total_loss: 0.0744311586022377
#       vf_explained_var: 0.8039760589599609
#       vf_loss: 0.003974197257775813
#   num_steps_sampled: 600600
#   num_steps_trained: 600600
# iterations_since_restore: 1001
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 36.36
#   ram_util_percent: 57.11
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.052575362526022185
#   mean_env_wait_ms: 4.735459307051472
#   mean_inference_ms: 2.0870476385162173
#   mean_raw_obs_processing_ms: 0.12184379624626848
# time_since_restore: 6470.113153457642
# time_this_iter_s: 7.0267438888549805
# time_total_s: 6470.113153457642
# timers:
#   learn_throughput: 247.667
#   learn_time_ms: 2422.61
#   sample_throughput: 129.825
#   sample_time_ms: 4621.619
#   update_time_ms: 2.358
# timestamp: 1617762253
# timesteps_since_restore: 0
# timesteps_total: 600600
# training_iteration: 1001
#
# checkpoint saved at /home/azibit/ray_results/PPO_unity_env_2021-04-06_19-35-27wu402w3o/checkpoint_1001/checkpoint-1001
# custom_metrics: {}
# date: 2021-04-06_21-24-20
# done: false
# episode_len_mean: 250.0
# episode_reward_max: -0.9999999310821295
# episode_reward_mean: -0.9999999310821295
# episode_reward_min: -0.9999999310821295
# episodes_this_iter: 2
# episodes_total: 2405
# experiment_id: a88c6111ff18408aad4cfbb03e696fbe
# hostname: azibit-Lenovo-Y520-15IKBM
# info:
#   learner:
#     default_policy:
#       allreduce_latency: 0.0
#       cur_kl_coeff: 3.4171875000000003
#       cur_lr: 5.0e-05
#       entropy: 1.1093323975801468
#       entropy_coeff: 0.0
#       kl: 0.012459455989301205
#       policy_loss: -0.23419222980737686
#       total_loss: -0.18609691224992275
#       vf_explained_var: 0.6578887701034546
#       vf_loss: 0.005519046710105613
#   num_steps_sampled: 601200
#   num_steps_trained: 601200
# iterations_since_restore: 1002
# node_ip: 192.168.1.4
# num_healthy_workers: 1
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 37.17
#   ram_util_percent: 57.080000000000005
# pid: 18605
# policy_reward_max: {}
# policy_reward_mean: {}
# policy_reward_min: {}
# sampler_perf:
#   mean_action_processing_ms: 0.05258036002107953
#   mean_env_wait_ms: 4.735792965592194
#   mean_inference_ms: 2.087235829994567
#   mean_raw_obs_processing_ms: 0.12185420633385807
# time_since_restore: 6477.159361839294
# time_this_iter_s: 7.046208381652832
# time_total_s: 6477.159361839294
# timers:
#   learn_throughput: 248.318
#   learn_time_ms: 2416.261
#   sample_throughput: 130.042
#   sample_time_ms: 4613.892
#   update_time_ms: 2.365
# timestamp: 1617762260
# timesteps_since_restore: 0
# timesteps_total: 601200
# training_iteration: 1002

# %%
trainer

# %%
## Trying to test the trained agent on an environment

env = AnimalAIGym(
            environment_filename = "../examples/env/AnimalAI",
            worker_id = 150,
            flatten_branched = True,
            uint8_visual = True,
            arenas_configurations = ArenaConfig('../examples/configurations/curriculum/0.yml')
)
# Out:
# INFO:mlagents_envs:Connected to Unity environment with package version 0.15.0-preview and communication version 0.15.0
# INFO:mlagents_envs:Connected new brain:
# AnimalAI?team=0
# INFO:gym_unity:1 agents within environment.

# %%
# run for number of steps
episode_reward = 0
done = False
recurrent_initial_state = trainer.get_policy().model.get_initial_state()
obs = env.reset()


# print(obs.shape)
while not done:
    action = trainer.compute_action(obs, recurrent_initial_state)
    action, recurrent_initial_state = action[0], action[1]
    print("ACTION: ", action)
#     action, recurrent_initial_state = action[0], action[1]
    obs, reward, done, info = env.step(action)
    
    print("REWARD: ", reward)
#     print(info)
    episode_reward += reward
# Out:
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  6
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  1
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  4
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  5
# REWARD:  -0.0039999997
# ACTION:  8
# REWARD:  -0.0039999997
# ACTION:  2
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  7
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997
# ACTION:  3
# REWARD:  -0.0039999997
# ACTION:  0
# REWARD:  -0.0039999997

# %%
episode_reward
# Out:
# -0.9999999310821295

# %%
env.close()
# Out:
# INFO:mlagents_envs:Environment shut down with return code 0.
